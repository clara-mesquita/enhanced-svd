# %%
import numpy as np
import pandas as pd
import os
import glob
import re
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import importlib.util
import sys

# %%
# DATA_DIR = "../cesnet-institutions-throughput/institutions/agg_1_hour_missing"
# TRUE_DATASET = "../cesnet-institutions-throughput/institutions/agg_1_hour"
BASELINE_DIR = "./baseline"
# OUTPUT_DIR = "./imputed_results"
# EVALUATION_FILE = "./evaluation_results.csv"
# PARTIAL_EVALUATION_FILE = "./resultados_parciais_avaliacao.csv"


# os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def load_imputation_functions():
    """Carrega todas as funções de imputação dos arquivos na pasta baselines e temporal_svd_knn"""
    functions = {}
    # Lista de diretórios para procurar por funções de imputação
    directories = [BASELINE_DIR, './temporal_svd_knn']
    
    for directory in directories:
        if not os.path.exists(directory):
            print(f"Diretório {directory} não encontrado. Pulando...")
            continue
            
        baseline_files = glob.glob(os.path.join(directory, "*.py"))
        
        for file_path in baseline_files:
            try:
                # Extrair nome do módulo
                module_name = os.path.splitext(os.path.basename(file_path))[0]
                
                # Carregar módulo
                spec = importlib.util.spec_from_file_location(module_name, file_path)
                module = importlib.util.module_from_spec(spec)
                sys.modules[module_name] = module
                spec.loader.exec_module(module)
                
                # Encontrar função de imputação (assumindo que começa com "impute_")
                for attr_name in dir(module):
                    if attr_name.startswith("impute_"):
                        functions[attr_name.replace("impute_", "")] = getattr(module, attr_name)
                        print(f"Carregada função: {attr_name} de {file_path}")
                
            except Exception as e:
                print(f"Erro ao carregar {file_path}: {e}")
    
    return functions

# %%
def process_datasets(data_dir, output_dir):
    """Processa todos os datasets no diretório"""
    
    # Carregar funções de imputação
    imputation_functions = load_imputation_functions()
    if not imputation_functions:
        print("Nenhuma função de imputação encontrada!")
        return
    
    # Encontrar todos os arquivos com padrão de nome
    pattern = os.path.join(data_dir, "*_esmond_data_*.csv")
    data_files = glob.glob(pattern)
    
    if not data_files:
        print(f"Nenhum arquivo encontrado com o padrão: {pattern}")
        return
    
    print(f"Encontrados {len(data_files)} arquivos para processar")
    
    rx = re.compile(
    r"""^
    (?P<prefix>.+?)_esmond_data_        # bbr (ou outro prefixo)
    (?P<link>[A-Za-z]{2}-[A-Za-z]{2})_  # go-se, ac-ap, etc.
    (?P<years>\d{4}(?:-\d{4})?)         # 2025 ou 2024-2025
    \.csv$
    """,
    re.VERBOSE | re.IGNORECASE,
)
    
    for file_path in data_files:
        try:
            # Extrair informações do nome do arquivo
            filename = os.path.basename(file_path)
            match = rx.match(filename)
            
            if not match:
                print(f"Padrão de nome inválido: {filename}")
                continue
                
            protocol = match["prefix"]
            link = match["link"].lower()        

            print(f"Processando: {filename} (ID: {protocol}, Taxa: {link}%)")
            
            # Carregar dataset
            df_missing = pd.read_csv(file_path)

            df_missing = df_missing.rename(columns={"Data": "time", "Vazao": "throughput_bps"})
            
            # Verificar se a coluna throughput_bps existe
            if "throughput_bps" not in df_missing.columns:
                print(f"Coluna 'throughput_bps' não encontrada em {filename}")
                continue            
            
            # Aplicar cada método de imputação
            for method_name, impute_func in imputation_functions.items():
                try:
                    print(f"  Aplicando {method_name}...")
                    
                    if impute_func.__name__ == 'impute_throughput_svd_knn':
                        df_imputed = impute_func(
                            df_missing,
                            col="throughput_bps",
                            min_period=24,
                            max_period=1000,
                            energy=0.9,
                            k=10,
                            allow_future=True
                        )
                    else:
                        df_imputed = impute_func(df_missing.copy())
                    
                    # Salvar resultados
                    output_file = os.path.join(output_dir, f"{protocol}_{link}_{method_name}.csv")
                    df_imputed.to_csv(output_file, index=False)
                    
                    print(f"    {method_name} concluído e salvo em {output_file}")
                    
                except Exception as e:
                    print(f"    Erro ao aplicar {method_name}: {str(e)}")
                    continue
                    
        except Exception as e:
            print(f"Erro ao processar {file_path}: {str(e)}")
            continue

# %%
DATA_DIR = "../vazao-escolhidos"
OUTPUT_DIR = "./results_rnp/imputed_original"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# Executar o processamento
process_datasets(DATA_DIR, OUTPUT_DIR)
# Out:
# Carregada função: impute_arima de ./baseline/arima.py
# Carregada função: impute_pca de ./baseline/pca.py
# Carregada função: impute_kalman de ./baseline/kalman_arima.py
# Carregada função: impute_softimpute de ./baseline/soft_impute.py
# Carregada função: impute_knn_imputer de ./baseline/knn.py
# Carregada função: impute_linear_interpolation de ./baseline/linear_interpolation.py
# Carregada função: impute_moving_average de ./baseline/moving_average.py
# Carregada função: impute_throughput_svd_knn de ./temporal_svd_knn/temporal_svd_knn.py
# Encontrados 200 arquivos para processar
# Processando: bbr_esmond_data_go-se_2024-2025.csv (ID: bbr, Taxa: go-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_go-se_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ac-go_2024-2025.csv (ID: bbr, Taxa: ac-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ac-go_throughput_svd_knn.csv
# Processando: cubic_esmond_data_se-es_2024-2025.csv (ID: cubic, Taxa: se-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_se-es_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ap-ba_2024-2025.csv (ID: bbr, Taxa: ap-ba%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ba_throughput_svd_knn.csv
# Processando: bbr_esmond_data_go-pb_2024-2025.csv (ID: bbr, Taxa: go-pb%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_go-pb_throughput_svd_knn.csv
# Processando: bbr_esmond_data_se-ms_2024-2025.csv (ID: bbr, Taxa: se-ms%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_se-ms_throughput_svd_knn.csv
# Processando: cubic_esmond_data_pb-se_2024-2025.csv (ID: cubic, Taxa: pb-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_pb-se_throughput_svd_knn.csv
# Processando: bbr_esmond_data_es-mt_2024-2025.csv (ID: bbr, Taxa: es-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_es-mt_throughput_svd_knn.csv
# Processando: bbr_esmond_data_mt-ac_2024-2025.csv (ID: bbr, Taxa: mt-ac%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_mt-ac_throughput_svd_knn.csv
# Processando: bbr_esmond_data_go-ce_2024-2025.csv (ID: bbr, Taxa: go-ce%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_go-ce_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ac-to_2024-2025.csv (ID: cubic, Taxa: ac-to%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ac-to_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ba-to_2024-2025.csv (ID: cubic, Taxa: ba-to%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ba-to_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ap-mt_2024-2025.csv (ID: bbr, Taxa: ap-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ap-mt_throughput_svd_knn.csv
# Processando: cubic_esmond_data_es-se_2024-2025.csv (ID: cubic, Taxa: es-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_es-se_throughput_svd_knn.csv
# Processando: bbr_esmond_data_es-ro_2024-2025.csv (ID: bbr, Taxa: es-ro%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_es-ro_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ap-go_2024-2025.csv (ID: bbr, Taxa: ap-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ap-go_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ac-pb_2024-2025.csv (ID: bbr, Taxa: ac-pb%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ac-pb_throughput_svd_knn.csv
# Processando: bbr_esmond_data_mt-go_2024-2025.csv (ID: bbr, Taxa: mt-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_mt-go_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ap-ms_2024-2025.csv (ID: bbr, Taxa: ap-ms%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ap-ms_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ap-pa_2024-2025.csv (ID: cubic, Taxa: ap-pa%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ap-pa_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ap-ms_2024-2025.csv (ID: cubic, Taxa: ap-ms%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ap-ms_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ba-es_2024-2025.csv (ID: bbr, Taxa: ba-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ba-es_throughput_svd_knn.csv
# Processando: cubic_esmond_data_go-mt_2024-2025.csv (ID: cubic, Taxa: go-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_go-mt_throughput_svd_knn.csv
# Processando: bbr_esmond_data_pb-ac_2024-2025.csv (ID: bbr, Taxa: pb-ac%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_pb-ac_throughput_svd_knn.csv
# Processando: cubic_esmond_data_es-ba_2024-2025.csv (ID: cubic, Taxa: es-ba%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_es-ba_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ce-ac_2024-2025.csv (ID: cubic, Taxa: ce-ac%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ac_throughput_svd_knn.csv
# Processando: cubic_esmond_data_go-ce_2024-2025.csv (ID: cubic, Taxa: go-ce%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_go-ce_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ce-go_2024-2025.csv (ID: bbr, Taxa: ce-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ce-go_throughput_svd_knn.csv
# Processando: cubic_esmond_data_go-se_2024-2025.csv (ID: cubic, Taxa: go-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_go-se_throughput_svd_knn.csv
# Processando: cubic_esmond_data_se-ms_2024-2025.csv (ID: cubic, Taxa: se-ms%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_se-ms_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ba-es_2024-2025.csv (ID: cubic, Taxa: ba-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ba-es_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ce-ap_2024-2025.csv (ID: cubic, Taxa: ce-ap%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ce-ap_throughput_svd_knn.csv
# Processando: bbr_esmond_data_pa-ap_2024-2025.csv (ID: bbr, Taxa: pa-ap%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_pa-ap_throughput_svd_knn.csv
# Processando: bbr_esmond_data_se-to_2024-2025.csv (ID: bbr, Taxa: se-to%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_se-to_throughput_svd_knn.csv
# Processando: bbr_esmond_data_to-pb_2024-2025.csv (ID: bbr, Taxa: to-pb%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_to-pb_throughput_svd_knn.csv
# Processando: bbr_esmond_data_to-mt_2024-2025.csv (ID: bbr, Taxa: to-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_to-mt_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ac-se_2024-2025.csv (ID: bbr, Taxa: ac-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ac-se_throughput_svd_knn.csv
# Processando: bbr_esmond_data_se-go_2024-2025.csv (ID: bbr, Taxa: se-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_se-go_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ms-ro_2024-2025.csv (ID: cubic, Taxa: ms-ro%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ms-ro_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ms-mt_2024-2025.csv (ID: bbr, Taxa: ms-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ms-mt_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ro-go_2024-2025.csv (ID: bbr, Taxa: ro-go%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ro-go_throughput_svd_knn.csv
# Processando: bbr_esmond_data_mt-es_2024-2025.csv (ID: bbr, Taxa: mt-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_mt-es_throughput_svd_knn.csv
# Processando: cubic_esmond_data_pa-ce_2024-2025.csv (ID: cubic, Taxa: pa-ce%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_pa-ce_throughput_svd_knn.csv
# Processando: cubic_esmond_data_go-es_2024-2025.csv (ID: cubic, Taxa: go-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_go-es_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ms-ce_2024-2025.csv (ID: bbr, Taxa: ms-ce%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ms-ce_throughput_svd_knn.csv
# Processando: bbr_esmond_data_go-mt_2024-2025.csv (ID: bbr, Taxa: go-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_go-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_go-mt_pca.csv
#   Aplicando kalman...
# ...
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ba-ap_throughput_svd_knn.csv
# Processando: cubic_esmond_data_mt-to_2024-2025.csv (ID: cubic, Taxa: mt-to%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_mt-to_throughput_svd_knn.csv
# Processando: bbr_esmond_data_pb-mt_2024-2025.csv (ID: bbr, Taxa: pb-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_pb-mt_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ac-es_2024-2025.csv (ID: cubic, Taxa: ac-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ac-es_throughput_svd_knn.csv
# Processando: cubic_esmond_data_go-ap_2024-2025.csv (ID: cubic, Taxa: go-ap%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_go-ap_throughput_svd_knn.csv
# Processando: cubic_esmond_data_es-am_2024-2025.csv (ID: cubic, Taxa: es-am%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_es-am_throughput_svd_knn.csv
# Processando: bbr_esmond_data_es-pb_2024-2025.csv (ID: bbr, Taxa: es-pb%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_es-pb_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ms-se_2024-2025.csv (ID: cubic, Taxa: ms-se%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ms-se_throughput_svd_knn.csv
# Processando: bbr_esmond_data_to-ba_2024-2025.csv (ID: bbr, Taxa: to-ba%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_to-ba_throughput_svd_knn.csv
# Processando: bbr_esmond_data_es-pa_2024-2025.csv (ID: bbr, Taxa: es-pa%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_es-pa_throughput_svd_knn.csv
# Processando: cubic_esmond_data_es-pi_2024-2025.csv (ID: cubic, Taxa: es-pi%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_es-pi_throughput_svd_knn.csv
# Processando: cubic_esmond_data_es-ro_2024-2025.csv (ID: cubic, Taxa: es-ro%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_es-ro_throughput_svd_knn.csv
# Processando: cubic_esmond_data_pb-ap_2024-2025.csv (ID: cubic, Taxa: pb-ap%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_pb-ap_throughput_svd_knn.csv
# Processando: bbr_esmond_data_ap-pb_2024-2025.csv (ID: bbr, Taxa: ap-pb%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/bbr_ap-pb_throughput_svd_knn.csv
# Processando: cubic_esmond_data_ap-mt_2024-2025.csv (ID: cubic, Taxa: ap-mt%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_ap-mt_throughput_svd_knn.csv
# Processando: cubic_esmond_data_mt-es_2024-2025.csv (ID: cubic, Taxa: mt-es%)
#   Aplicando arima...
#     arima concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_arima.csv
#   Aplicando pca...
#     pca concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_pca.csv
#   Aplicando kalman...
#     kalman concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_kalman.csv
#   Aplicando softimpute...
#     softimpute concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_softimpute.csv
#   Aplicando knn_imputer...
#     knn_imputer concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_knn_imputer.csv
#   Aplicando linear_interpolation...
#     linear_interpolation concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_linear_interpolation.csv
#   Aplicando moving_average...
#     moving_average concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_moving_average.csv
#   Aplicando throughput_svd_knn...
#     throughput_svd_knn concluído e salvo em ./results_rnp/imputed_original/cubic_mt-es_throughput_svd_knn.csv
